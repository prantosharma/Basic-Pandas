# %%
import pandas as pd

# %%
df=pd.read_excel('stocks_3_levels.xlsx',header=[0,1,2])
df
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df.stack()
# Out:
#                                            Income Statement  Price Ratios  \
# 0 Company   Unnamed: 0_level_1                          NaN           NaN
#   Facebook  Net Profit                                 0.80           NaN
#             Net Sales                                  2.60           NaN
#             Price                                       NaN        155.00
#             Price to earnings ratio (P/E)               NaN         37.10
#   Google    Net Profit                                 5.43           NaN
#             Net Sales                                 20.00           NaN
#             Price                                       NaN        955.00
#             Price to earnings ratio (P/E)               NaN         32.00
#   Microsoft Net Profit                                 4.56           NaN
#             Net Sales                                 18.70           NaN
#             Price                                       NaN         66.00
# ...

# %%
df.stack(level=0)
# Out:
#                                 Net Profit  Net Sales   Price  \
# 0 Company   Unnamed: 0_level_0         NaN        NaN     NaN
#   Facebook  Income Statement          0.80       2.60     NaN
#             Price Ratios               NaN        NaN   155.0
#   Google    Income Statement          5.43      20.00     NaN
#             Price Ratios               NaN        NaN   955.0
#   Microsoft Income Statement          4.56      18.70     NaN
#             Price Ratios               NaN        NaN    66.0
# 1 Company   Unnamed: 0_level_0         NaN        NaN     NaN
#   Facebook  Income Statement          0.97       3.10     NaN
#             Price Ratios               NaN        NaN   150.0
#   Google    Income Statement          5.89      22.00     NaN
#             Price Ratios               NaN        NaN   987.0
#   Microsoft Income Statement          5.10      21.30     NaN
#             Price Ratios               NaN        NaN    69.0
# ...

# %%
df1.unstack()
# Out:
#             Income Statement                                                \
#                   Net Profit Net Sales Price Price to earnings ratio (P/E)
# 0 Company                NaN       NaN   NaN                           NaN
#   Facebook              0.80      2.60   NaN                           NaN
#   Google                5.43     20.00   NaN                           NaN
#   Microsoft             4.56     18.70   NaN                           NaN
# 1 Company                NaN       NaN   NaN                           NaN
#   Facebook              0.97      3.10   NaN                           NaN
#   Google                5.89     22.00   NaN                           NaN
#   Microsoft             5.10     21.30   NaN                           NaN
# 2 Company                NaN       NaN   NaN                           NaN
#   Facebook              1.20      4.30   NaN                           NaN
# ...
